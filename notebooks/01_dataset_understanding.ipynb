# %%
import pandas as pd

df = pd.read_csv("../data/raw/Metro_Interstate_Traffic_Volume.csv")

# %%
df
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0         NaN  288.28      0.0      0.0          40        Clouds
# 1         NaN  289.36      0.0      0.0          75        Clouds
# 2         NaN  289.58      0.0      0.0          90        Clouds
# 3         NaN  290.13      0.0      0.0          90        Clouds
# 4         NaN  291.14      0.0      0.0          75        Clouds
# ...       ...     ...      ...      ...         ...           ...
# 48199     NaN  283.45      0.0      0.0          75        Clouds
# 48200     NaN  282.76      0.0      0.0          90        Clouds
# 48201     NaN  282.73      0.0      0.0          90  Thunderstorm
# 48202     NaN  282.09      0.0      0.0          90        Clouds
# 48203     NaN  282.12      0.0      0.0          90        Clouds
#
#           weather_description            date_time  traffic_volume
# 0            scattered clouds  2012-10-02 09:00:00            5545
# ...

# %%
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     NaN  288.28      0.0      0.0          40       Clouds
# 1     NaN  289.36      0.0      0.0          75       Clouds
# 2     NaN  289.58      0.0      0.0          90       Clouds
# 3     NaN  290.13      0.0      0.0          90       Clouds
# 4     NaN  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     NaN  288.28      0.0      0.0          40       Clouds
# 1     NaN  289.36      0.0      0.0          75       Clouds
# 2     NaN  289.58      0.0      0.0          90       Clouds
# 3     NaN  290.13      0.0      0.0          90       Clouds
# 4     NaN  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
df.shape
# Out:
# (48204, 9)

# %%
df.columns
# Out:
# Index(['holiday', 'temp', 'rain_1h', 'snow_1h', 'clouds_all', 'weather_main',
#        'weather_description', 'date_time', 'traffic_volume'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              61 non-null     object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  object
#  8   traffic_volume       48204 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.3+ MB

# %%
df.describe()
# Out:
#                temp       rain_1h       snow_1h    clouds_all  traffic_volume
# count  48204.000000  48204.000000  48204.000000  48204.000000    48204.000000
# mean     281.205870      0.334264      0.000222     49.362231     3259.818355
# std       13.338232     44.789133      0.008168     39.015750     1986.860670
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%      272.160000      0.000000      0.000000      1.000000     1193.000000
# 50%      282.450000      0.000000      0.000000     64.000000     3380.000000
# 75%      291.806000      0.000000      0.000000     90.000000     4933.000000
# max      310.070000   9831.300000      0.510000    100.000000     7280.000000

# %%
df.isnull().sum()
# Out:
# holiday                48143
# temp                       0
# rain_1h                    0
# snow_1h                    0
# clouds_all                 0
# weather_main               0
# weather_description        0
# date_time                  0
# traffic_volume             0
# dtype: int64

# %% [markdown]
# What are we trying to solve?
# We want to understand traffic patterns and predict traffic volume based on factors such as weather, time, and holidays.

# %% [markdown]
# What are the features?
# Features:
#
# date_time
# temp
# holiday
# weather_main
# weather_description
# rain_1h
# snow_1h
# clouds_all

# %% [markdown]
# How might these affect traffic?
# date_time:
# Peak office hours may increase traffic.
#
# holiday:
# Traffic may decrease during holidays.
#
# temp:
# Extreme temperatures may affect travel patterns.
#
# weather_main:
# Rain and snow can increase congestion.
#
# clouds_all:
# May indicate changing weather conditions.

# %%
df.duplicated().sum()
# Out:
# np.int64(17)

# %% [markdown]
# What is our target variable?
# Target Variable: traffic_volume
#
# Reason:
#
# Traffic volume represents the number of vehicles on the road.
#
# This is what we want to predict using other information.

# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.analytics.temporal import peak_hour_analysis

df = pd.read_csv("../data/raw/Metro_Interstate_Traffic_Volume.csv")

result = peak_hour_analysis(df)

result
from src.analytics.temporal import weekday_vs_weekend_analysis

result = weekday_vs_weekend_analysis(df)

result
# Out:
#   day_type  average_traffic  max_traffic  min_traffic  std_deviation  \
# 0  Weekday          3533.60         7280            1        2074.13
# 1  Weekend          2570.51         6645            0        1546.48
#
#    observations
# 0         34501
# 1         13703

# %%
from src.analytics.temporal import weekday_vs_weekend_analysis

result = weekday_vs_weekend_analysis(df)

result
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.analytics.temporal import weekday_vs_weekend_analysis
#       3 result = weekday_vs_weekend_analysis(df)
#       5 result
#
# ModuleNotFoundError: No module named 'src'
